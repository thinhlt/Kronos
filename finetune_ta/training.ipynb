# %%
# !torchrun --nproc_per_node=1 train_sequence.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Installing project requirements...')
# !pip install -r /content/drive/MyDrive/Kronos/requirements.txt
# Out:
# Installing project requirements...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.4/515.4 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 116.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.8/485.8 kB 46.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.9/396.9 kB 42.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.8.0
#     Uninstalling safetensors-0.8.0:
#       Successfully uninstalled safetensors-0.8.0
#   Attempting uninstall: einops
# ...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import torch
torch.cuda.empty_cache()
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu")
print("Free MiB:", round(torch.cuda.mem_get_info()[0] / 1024**2) if torch.cuda.is_available() else "n/a")

# !python /content/drive/MyDrive/Kronos/train_sequential.py --config /content/drive/MyDrive/Kronos/config_multi_symbol_5m_ta_norm.yaml
# Out:
# GPU: NVIDIA L4
# Free MiB: 22369
# Using device: cuda:0 (rank=0, world_size=1, local_rank=0)
# ...
# Kronos technical-indicator finetuning configuration summary
# ...
# Experiment name: multi_symbol_5m_ta_norm
# Data path: /content/drive/MyDrive/Kronos/data/*.csv
# Resolved data files (10): ['/content/drive/MyDrive/Kronos/data/ADAUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/AVAXUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/BNBUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/BTCUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/DOGEUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/ETHUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/SOLUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/TRXUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/XRPUSDT_kline_5m_norm.csv', '/content/drive/MyDrive/Kronos/data/ZECUSDT_kline_5m_norm.csv']
# ...
